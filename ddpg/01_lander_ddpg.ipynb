# %% [markdown]
# [__DDPG Phil Tabor__](https://github.com/philtabor/Actor-Critic-Methods-Paper-To-Code/blob/master/DDPG/ddpg_torch.py)<br>
# [__DDPG Maths__](https://spinningup.openai.com/en/latest/algorithms/ddpg.html)

# %%
import pandas as pd
import numpy as np
import re
import os
import importlib

from collections import deque
import matplotlib.pyplot as plt
import seaborn as sns
import gymnasium as gym
sns.set_theme()

import ddpg
importlib.reload(ddpg)

from IPython.display import clear_output

import torch as T
import numpy as np
from torch import cuda, device, distributions
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
env_id = 'LunarLanderContinuous-v2'
env = gym.make(env_id)#,render_mode="human")

s_size = env.observation_space.shape[0]
a_size = env.action_space.shape[0]

print("_____OBSERVATION SPACE_____ \n")
print("The State Space is: ", s_size)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# The State Space is:  8
# Sample observation [ 0.19394366  1.2381698  -1.2940702  -0.7694533   0.23970042 -0.0203226
#   0.46036744  0.45468247]

# %%
env = gym.make('LunarLanderContinuous-v2')

avg_win_size = 50
epi_results = deque(maxlen=avg_win_size)
episodes = 100_000
lr_actor = 0.001
lr_critic = 0.0001

agent = ddpg.Agent(actor_lr=lr_actor, critic_lr=lr_critic, 
              s_size=s_size, tau=0.001,
              batch_size=64, lyr1=128, lyr2=256, 
              a_size=a_size,
             )

# %%
# model and log file names
log_file_name = os.path.join('.','artefacts',f'{env_id}_ddpg.csv')
model_file = os.path.join('.','models',f'{env_id}_ddpg.pth')

# %%
#score_history = []
train = False

if train:
    # Delete old trainig log if exists
    if os.path.exists(log_file_name):
        os.remove(log_file_name)

    log_file = open(log_file_name, "w")
    log_file.write(f'episode,rewards\n')
    
    for epi in range(episodes):
        s, _ = env.reset()
        done = False
        rewards = 0
        step = 0
        while not done:
            act = agent.choose_action(s)
            s_, r, done, info, _ = env.step(act)
            rewards += r
            step += 1
            if step>1000:
                done = True

            agent.memory.store(s, act, r, s_, done)
            agent.learn()

            s = s_
 
        #score_history.append(score)
        #avg_score = np.mean(score_history[-100:])

        epi_results.append(rewards)
        log_file.write(f'{epi},{rewards:.2f}\n')

        if epi % 10 == 0:
            print(f"episode {epi:>5}  score {rewards:+7.2f}  avg score {np.mean(epi_results):+7.2f}")

        if epi % 100 == 0:
            clear_output()

        if np.mean(epi_results) > 200:
            print('saving models')
            agent.save_model(model_file)
            break
    log_file.close()

# %%
df = pd.read_csv(log_file_name)
df['mean_rewards'] = df['rewards'].rolling(avg_win_size).mean()

fig,ax=plt.subplots(1,1,sharex='col',sharey= False,figsize=(5,4))

sns.lineplot(df['rewards'], ax = ax)
sns.lineplot(df['mean_rewards'],ax = ax)
ax.set_title('Rewards & Mean Rewards',fontsize=8)
# Out:
# Text(0.5, 1.0, 'Rewards & Mean Rewards')

# %%
eval_agent = ddpg.Agent(actor_lr=lr_actor, critic_lr=lr_critic, 
              s_size=s_size, tau=0.001,
              batch_size=64, lyr1=128, lyr2=256, 
              a_size=a_size,
             )
eval_agent.load_model(model_file)

# %%
eval_env = gym.make(env_id,render_mode="human")
for epi in range(10):
    s, _ = eval_env.reset()
    done = False
    score = 0
    steps = 0
    while not done:
        act = eval_agent.choose_action(s)*2
        s_, r, _, done, _ = eval_env.step(act)
        steps += 1
        score += r
        
        if score > 220:
            done = True
        
        #agent.memory.store(s, act, r, s_, done)
        #agent.learn()
        
        s = s_
    print(f'{score:.2f}')
eval_env.close()
# Out:
# 319.20
# 309.14
# 228.16
# 262.03
# 233.24
# 246.01
# 242.82
# 308.23
# 159.76
# 285.30
